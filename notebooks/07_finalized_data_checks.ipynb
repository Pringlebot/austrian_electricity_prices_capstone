# %%
# =============================================================================
# Imports
# =============================================================================

import pandas as pd
import openpyxl
import numpy as np
from pathlib import Path
from datetime import datetime
import warnings

# %%
#load consolidated data
df = pd.read_csv('../data/processed/data_consolidated.csv')

# %%
# =============================================================================
# Finishing touches and data checks 
# =============================================================================#

df['date_dt'] = pd.to_datetime(df['date']) 
#caution: date_dt needs to be parsed as datetime object when loaded in any other notebook!

# %%
# =============================================================================
# Exporting Descriptive Statistics for meta-data
# =============================================================================

df.info() #display data info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4663 entries, 0 to 4662
# Data columns (total 60 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  4663 non-null   object
#  1   year                                  4663 non-null   float64
#  2   month                                 4663 non-null   float64
#  3   quarter                               4663 non-null   float64
#  4   week                                  4663 non-null   float64
#  5   aggregation_level                     4663 non-null   object
#  6   price_exaa_mean                       3440 non-null   float64
#  7   price_mc_auction_mean                 2439 non-null   float64
#  8   price_count_exaa                      4590 non-null   float64
#  9   price_count_mc                        4590 non-null   float64
# ...

# %%
# Export descriptive statistics to CSV for meta-data
with open('../data/metadata/info_output.txt', 'w') as f:
    df.info(buf=f)

# %%
df.describe() #display descriptive statistics
# Out:
#               year        month      quarter         week  price_exaa_mean  \
# count  4663.000000  4663.000000  4663.000000  4663.000000      3440.000000
# mean   2019.718207     6.387948     2.466867    26.040746        73.641860
# min    2009.000000     1.000000     1.000000     1.000000       -13.000000
# 25%    2017.000000     3.000000     1.000000    13.000000        30.000000
# 50%    2020.000000     6.000000     2.000000    26.000000        39.000000
# 75%    2022.000000     9.000000     3.000000    39.000000        60.000000
# max    2025.000000    12.000000     4.000000    53.000000       727.000000
# std       3.235956     3.427662     1.110443    14.971618        92.333672
#
#        price_mc_auction_mean  price_count_exaa  price_count_mc  \
# count            2439.000000       4590.000000     4590.000000
# mean              114.209102        183.166013      129.853595
# min               -23.000000          0.000000        0.000000
# ...

# %%
# Export descriptive statistics to CSV for meta-data
df.describe().round(2).to_csv('../data/metadata/describe_output.csv', sep=';', decimal=',')

# %%
#Export finalized dataframe to csv
df.to_csv('../data/processed/data_finalized.csv', index=False)
